# %% [markdown]
# # SP Assignment #2

# %%
import pandas as pd
import numpy as np

# %%
df_columns = pd.read_csv('columns_description.csv')
df_raw = pd.read_csv('infringement_dataset.csv')

# %%
df_columns
# Out:
#                     New name  \
# 0                        age
# 1              annual_income
# 2                    car_age
# 3              contract_type
# 4              credit_amount
# 5             credit_annuity
# 6              days_employed
# 7                  education
# 8              family_status
# 9                 first_name
# 10                    gender
# 11           goods_valuation
# 12               has_own_car
# 13            has_own_realty
# 14              housing_type
# 15               income_type
# 16                 infringed
# 17                 last_name
# 18                   loan_id
# 19     mobilephone_reachable
# 20              num_children
# 21        num_family_members
# 22        num_req_bureau_day
# 23       num_req_bureau_hour
# 24      num_req_bureau_month
# 25        num_req_bureau_qrt
# 26       num_req_bureau_week
# 27       num_req_bureau_year
# 28           occupation_type
# 29         organization_type
# 30   past_avg_amount_annuity
# ...

# %%
df_raw.head()
# Out:
#    loan_id  infringed    contract_type gender has_own_car has_own_realty  \
# 0   100002          1       Cash loans      M           N              Y
# 1   100003          0       Cash loans      F           N              N
# 2   100004          0  Revolving loans      M           Y              Y
# 3   100006          0       Cash loans      F           N              Y
# 4   100007          0       Cash loans      M           N              Y
#
#    num_children  annual_income  credit_amount  credit_annuity  ...  \
# 0             0       202500.0       406597.5         24700.5  ...
# 1             0       270000.0      1293502.5         35698.5  ...
# 2             0        67500.0       135000.0          6750.0  ...
# 3             0       135000.0       312682.5         29686.5  ...
# 4             0       121500.0       513000.0         21865.5  ...
#
#    first_name  last_name past_avg_amount_annuity past_avg_amt_application  \
# ...

# %%
df_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 307511 entries, 0 to 307510
# Data columns (total 46 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   loan_id                   307511 non-null  int64
#  1   infringed                 307511 non-null  int64
#  2   contract_type             307511 non-null  object
#  3   gender                    307511 non-null  object
#  4   has_own_car               307511 non-null  object
#  5   has_own_realty            307511 non-null  object
#  6   num_children              307511 non-null  int64
#  7   annual_income             307511 non-null  float64
#  8   credit_amount             307511 non-null  float64
#  9   credit_annuity            307499 non-null  float64
#  10  goods_valuation           307233 non-null  float64
#  11  income_type               307511 non-null  object
#  12  education                 307511 non-null  object
# ...

# %% [markdown]
# ## Data Cleaning

# %%
df_raw_clean = df_raw.drop(columns = ['score_ext_1','car_age','occupation_type'])
df_raw_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 307511 entries, 0 to 307510
# Data columns (total 43 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   loan_id                   307511 non-null  int64
#  1   infringed                 307511 non-null  int64
#  2   contract_type             307511 non-null  object
#  3   gender                    307511 non-null  object
#  4   has_own_car               307511 non-null  object
#  5   has_own_realty            307511 non-null  object
#  6   num_children              307511 non-null  int64
#  7   annual_income             307511 non-null  float64
#  8   credit_amount             307511 non-null  float64
#  9   credit_annuity            307499 non-null  float64
#  10  goods_valuation           307233 non-null  float64
#  11  income_type               307511 non-null  object
#  12  education                 307511 non-null  object
# ...

# %%
df_raw_clean = df_raw_clean.dropna(thresh=10)
df_raw_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 307511 entries, 0 to 307510
# Data columns (total 43 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   loan_id                   307511 non-null  int64
#  1   infringed                 307511 non-null  int64
#  2   contract_type             307511 non-null  object
#  3   gender                    307511 non-null  object
#  4   has_own_car               307511 non-null  object
#  5   has_own_realty            307511 non-null  object
#  6   num_children              307511 non-null  int64
#  7   annual_income             307511 non-null  float64
#  8   credit_amount             307511 non-null  float64
#  9   credit_annuity            307499 non-null  float64
#  10  goods_valuation           307233 non-null  float64
#  11  income_type               307511 non-null  object
#  12  education                 307511 non-null  object
# ...

# %%
df_raw_clean.to_csv('infringement_clean.csv')

# %% [markdown]
# ## Differential Privacy

# %%
def add_laplace_noise(s, sensitivity, epsilon):
  return s + np.random.laplace(loc=0, scale=sensitivity/epsilon)

def percentage_error(orig, est):
  return ((orig-est) / orig) * 100

# %%
df_query = df_raw_clean.query('infringed == 1')
